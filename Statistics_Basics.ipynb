# %% [markdown]
# question1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss
# nominal, ordinal, interval, and ratio scales
#
#  Qualitative Data (Categorical Data):
# This type of data describes characteristics or attributes that cannot be measured numerically. It is non-numeric and is used to categorize or label elements.
#
# Examples:
#
# Hair color (e.g., black, brown, blonde)
# Gender (e.g., male, female, non-binary)
# Types of cuisine (e.g., Italian, Chinese, Indian)
# Characteristics:
#
# Describes qualities or characteristics.
#
# Often grouped into categories or classes.
#
#
#  Quantitative Data (Numerical Data):
#
# This type of data consists of numbers and represents measurable quantities. It can be further divided into discrete and continuous data.
#
# Discrete Data:
#
# Consists of whole numbers or counts.
#
# Examples: Number of students in a class, number of cars in a parking lot.
# Continuous Data:
#
# Includes any value within a given range, often involving fractions or decimals.
# Examples: Height (e.g., 5.8 feet), weight (e.g., 68.5 kg), temperature (e.g., 36.6°C).
#
# Scales of Measurement
#
# Data is measured using four types of scales: Nominal, Ordinal, Interval, and Ratio.
#
#  Nominal Scale:
#
# This is the simplest scale, used to label or categorize data without implying any order or ranking.
#
# Characteristics:
#
# Categories are mutually exclusive.
# No inherent order or ranking.
# No mathematical operations can be performed.
# Examples:
#
# Blood groups (A, B, AB, O)
#
# Nationality (Indian, American, Canadian)
#
#  Ordinal Scale:
#
# This scale categorizes data with a meaningful order or ranking, but the differences between categories are not uniform.
#
# Characteristics:
#
# Provides a sense of order or hierarchy.
# Differences between ranks are not equal.
# Examples:
#
# Education levels (High school, Bachelor’s, Master’s, Ph.D.)
# Customer satisfaction ratings (Very Dissatisfied, Dissatisfied, Neutral, Satisfied, Very Satisfied)
#
#  Interval Scale:
#
# This scale measures data with equal intervals between values but lacks a true zero point.
#
# Characteristics:
#
# Equal intervals between values.
#
# Arithmetic operations like addition and subtraction are meaningful.
# No true zero (zero does not mean "nothing").
#
# Examples:
#
# Temperature in Celsius or Fahrenheit (0°C is not the absence of temperature).
# Dates in a calendar (e.g., 2025, 2026).
#
#  Ratio Scale:
#
# This scale has all the properties of an interval scale but includes a true zero point, which signifies the absence of the attribute being measured.
#
# Characteristics:
#
# Equal intervals between values.
# True zero point allows meaningful ratios.
# All mathematical operations (addition, subtraction, multiplication, and division) are possible.
# Examples:
#
# Weight (e.g., 0 kg means no weight).
# Height (e.g., 0 meters signifies no height).
# Income (e.g., $0 indicates no income).
# Summary Table
# Scale	Type of Data	Order	Equal Intervals	True Zero	Examples
# Nominal	Qualitative	No	No	No	Gender, Blood Type
# Ordinal	Qualitative	Yes	No	No	Education Level, Rankings
# Interval	Quantitative	Yes	Yes	No	Temperature, Calendar Dates
# Ratio	Quantitative	Yes	Yes	Yes	Weight, Height, Income
# Let me know if you’d like more clarification or examples!
#
#
#
#
#
#
#
# question2. What are the measures of central tendency, and when should you use each? Discuss the mean, median,
# and mode with examples and situations where each is appropriate.
#
#  Measures of Central Tendency
# Measures of central tendency describe a central or typical value for a dataset. The three main measures are mean, median, and mode.
#
#  Mean (Arithmetic Average):
# The mean is the sum of all data points divided by the number of data points.
#
# Formula:
#
# Mean
# =
# Sum of all values
# Number of values
# Mean=
# Number of values
# Sum of all values
# ​
#
# Example:
# For the data: 5, 10, 15, 20,
#
# Mean
# =
# 5
# +
# 10
# +
# 15
# +
# 20
# 4
# =
# 12.5
# Mean=
# 4
# 5+10+15+20
# ​
#  =12.5
# When to Use:
#
# Useful when data is evenly distributed without extreme outliers.
# Example: Average income in a region.
#  Median (Middle Value):
# The median is the middle value when the data is ordered from smallest to largest. If the dataset has an even number of observations, the median is the average of the two middle values.
#
# Example:
# For the data: 3, 8, 10, 17, 25 (odd count), the median = 10.
# For the data: 3, 8, 10, 17 (even count), the median =
# 8
# +
# 10
# 2
# =
# 9
# 2
# 8+10
# ​
#  =9.
#
# When to Use:
#
# Best for skewed data or when outliers are present.
#
# Example: Median household income in a city with income disparities.
#  Mode (Most Frequent Value):
#
# The mode is the value(s) that appear most frequently in a dataset. There can be one mode, more than one mode (bimodal or multimodal), or no mode.
#
# Example:
# For the data: 4, 4, 6, 6, 8, 9,
# Modes = 4 and 6 (bimodal).
#
# When to Use:
#
# Useful for categorical data or identifying the most common occurrence.
# Example: Determining the most popular ice cream flavor.
#
#  question3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?n
#
# Dispersion refers to the extent to which data points in a dataset are spread out or clustered around the central value. Common measures include variance and standard deviation.
#
# Variance:
#
# Variance quantifies the average squared deviation of each data point from the mean.
#
# Formula:
#
# Variance
# (
# 𝜎
# 2
# )
# =
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝜇
# )
# 2
# 𝑁
# Variance(σ
# 2
#  )=
# N
# ∑(x
# i
# ​
#  −μ)
# 2
#
# ​
#
# where
# 𝑥
# 𝑖
# x
# i
# ​
#   is each data point,
# 𝜇
# μ is the mean, and
# 𝑁
# N is the total number of data points.
#
# Example:
# For the data: 4, 6, 8, Mean = 6.
# Variance =
# (
# 4
# −
# 6
# )
# 2
# +
# (
# 6
# −
# 6
# )
# 2
# +
# (
# 8
# −
# 6
# )
# 2
# 3
# =
# 2.67
# 3
# (4−6)
# 2
#  +(6−6)
# 2
#  +(8−6)
# 2
#
# ​
#  =2.67.
#
# Standard Deviation (SD):
# The SD is the square root of the variance and measures the spread of data in the same units as the data.
#
# Formula:
#
# SD
# =
# Variance
# SD=
# Variance
# ​
#
# Example:
# Using the variance above (
# 2.67
# 2.67),
# SD =
# 2.67
# =
# 1.63
# 2.67
# ​
#  =1.63.
#
# Purpose:
#
# Variance and SD help in understanding the consistency or variability in data.
# Example: A lower SD for students’ test scores indicates consistent performance.
#
# question4. Box Plot
#
# A box plot (or whisker plot) is a graphical representation of data distribution based on five-number summaries: minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum.
#
# Key Components of a Box Plot:
# Box: Represents the interquartile range (IQR) from Q1 to Q3.
# Median Line: Divides the box into two parts.
# Whiskers: Extend from the box to the minimum and maximum values within 1.5 times the IQR.
# Outliers: Data points beyond the whiskers are plotted individually.
# What It Tells You:
# Data symmetry or skewness.
# Spread and variability of the data.
# Presence of outliers.
# Example: A box plot can show if students' scores in an exam are concentrated or spread out.
#
# question5. Role of Random Sampling in Inferences
#
# Random sampling is a technique used to select a subset of individuals from a population such that every individual has an equal chance of being chosen. This method ensures that the sample is representative of the population.
#
# Importance in Making Inferences:
# Unbiased Representation: Helps generalize findings to the entire population.
# Reduced Sampling Bias: Avoids over-representation of certain groups.
# Facilitates Statistical Analysis: Random samples allow the use of probability theory for making inferences about populations.
# Example:
# A survey is conducted on 500 randomly selected citizens to estimate the voting preferences of a city. Random sampling ensures the results reflect the opinions of the entire city, minimizing bias.
#
# Let me know if you'd like more details on any of these concepts!
#
#
#
#
#
#
#
#
#
# question6. Concept of Skewness and Its Types
#
# Skewness is a measure of the asymmetry of the distribution of data. It shows whether the data is symmetrically distributed or if it leans more towards one side.
#
# Types of Skewness:
# Symmetrical Distribution (Zero Skewness):
#
# The mean, median, and mode are equal.
# Example: Heights of individuals in a population often follow a symmetrical distribution.
# Positive Skewness (Right Skewed):
#
# The tail is longer on the right side of the distribution.
# Mean > Median > Mode.
# Example: Income distribution (a few high-income individuals skew the data).
# Negative Skewness (Left Skewed):
#
# The tail is longer on the left side of the distribution.
# Mean < Median < Mode.
# Example: Scores on an easy test where most students score high.
# Impact on Data Interpretation:
# Skewness affects the choice of central tendency measure. The median is more reliable than the mean for highly skewed data.
# Skewed distributions may require transformation (e.g., log transformation) for statistical modeling.
#
# question7. Interquartile Range (IQR) and Outlier Detection
# The Interquartile Range (IQR) measures the spread of the middle 50% of the data and is calculated as:
#
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1
# where
# 𝑄
# 1
# Q1 is the first quartile (25th percentile) and
# 𝑄
# 3
# Q3 is the third quartile (75th percentile).
#
# Outlier Detection:
# A data point is considered an outlier if it lies outside:
# [
# 𝑄
# 1
# −
# 1.5
# ×
# IQR
# ,
# 𝑄
# 3
# +
# 1.5
# ×
# IQR
# ]
# [Q1−1.5×IQR,Q3+1.5×IQR]
# Example:
# For the dataset:
# 1
# ,
# 3
# ,
# 5
# ,
# 7
# ,
# 9
# ,
# 11
# ,
# 100
# 1,3,5,7,9,11,100,
#
# 𝑄
# 1
# =
# 3
# Q1=3,
# 𝑄
# 3
# =
# 9
# Q3=9,
# IQR
# =
# 9
# −
# 3
# =
# 6
# IQR=9−3=6.
# Outlier bounds:
# [
# 3
# −
# 1.5
# ×
# 6
# ,
# 9
# +
# 1.5
# ×
# 6
# ]
# =
# [
# −
# 6
# ,
# 18
# ]
# [3−1.5×6,9+1.5×6]=[−6,18].
# Outlier:
# 100
# 100.
#
# question8. Binomial Distribution
#
#
# The binomial distribution models the probability of a fixed number of successes in a fixed number of independent trials, where each trial has the same probability of success.
#
# Conditions:
# A fixed number of trials (
# 𝑛
# n).
# Each trial has only two outcomes: success or failure.
# The probability of success (
# 𝑝
# p) is constant.
# Trials are independent.
# Formula:
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# where:
#
# 𝑘
# k: Number of successes.
# 𝑛
# n: Total trials.
# 𝑝
# p: Probability of success.
# Example:
# Tossing a coin 5 times (
# 𝑛
# =
# 5
# n=5) with
# 𝑝
# =
# 0.5
# p=0.5. Probability of getting exactly 3 heads:
#
# 𝑃
# (
# 𝑋
# =
# 3
# )
# =
# (
# 5
# 3
# )
# (
# 0.5
# )
# 3
# (
# 0.5
# )
# 2
# =
# 10
# ×
# 0.125
# ×
# 0.25
# =
# 0.3125
# P(X=3)=(
# 3
# 5
# ​
#  )(0.5)
# 3
#  (0.5)
# 2
#  =10×0.125×0.25=0.3125
#
# question9. Properties of Normal Distribution and the Empirical Rule
# Properties of Normal Distribution:
#
# Symmetrical and bell-shaped curve.
# Mean = Median = Mode.
# Defined by mean (
# 𝜇
# μ) and standard deviation (
# 𝜎
# σ).
# Total area under the curve = 1.
# Empirical Rule (68-95-99.7 Rule):
# 68% of data lies within 1 SD (
# 𝜇
# ±
# 𝜎
# μ±σ).
# 95% of data lies within 2 SDs (
# 𝜇
# ±
# 2
# 𝜎
# μ±2σ).
# 99.7% of data lies within 3 SDs (
# 𝜇
# ±
# 3
# 𝜎
# μ±3σ).
# Example:
# For a dataset with
# 𝜇
# =
# 50
# μ=50,
# 𝜎
# =
# 10
# σ=10:
#
# 68% of data falls between
# 40
# 40 and
# 60
# 60.
# 95% of data falls between
# 30
# 30 and
# 70
# 70.
# 99.7% of data falls between
# 20
# 20 and
# 80
# 80.
#
# question10. Poisson Process Example
#
# The Poisson process models the probability of a certain number of events occurring within a fixed interval, given the events occur independently.
#
# Formula:
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑒
# −
# 𝜆
# 𝜆
# 𝑘
# 𝑘
# !
# P(X=k)=
# k!
# e
# −λ
#  λ
# k
#
# ​
#
# where:
#
# 𝑘
# k: Number of events.
# 𝜆
# λ: Average rate of occurrence.
# Example:
# A call center receives 6 calls/hour (
# 𝜆
# =
# 6
# λ=6). Probability of receiving 4 calls in an hour:
#
# 𝑃
# (
# 𝑋
# =
# 4
# )
# =
# 𝑒
# −
# 6
# 6
# 4
# 4
# !
# =
# 0.00248
# ×
# 1296
# 24
# =
# 0.134
# P(X=4)=
# 4!
# e
# −6
#  6
# 4
#
# ​
#  =
# 24
# 0.00248×1296
# ​
#  =0.134
#
# question11. Random Variable: Discrete vs. Continuous
#
# A random variable is a variable representing numerical outcomes of a random process.
#
# Discrete Random Variable:
# Takes specific, countable values.
# Example: Number of heads in 5 coin tosses.
# Continuous Random Variable:
# Takes any value within a range or interval.
# Example: Weight of a randomly selected individual.
#
# question
# 12. Covariance and Correlation
#
# Example Dataset:
# X	Y
# 1	2
# 2	3
# 3	5
# 4	7
# Covariance Formula:
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# ∑
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# 𝑛
# Cov(X,Y)=
# n
# ∑(X
# i
# ​
#  −
# X
# ˉ
#  )(Y
# i
# ​
#  −
# Y
# ˉ
#  )
# ​
#
# Correlation Formula:
# 𝑟
# =
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# 𝜎
# 𝑋
# 𝜎
# 𝑌
# r=
# σ
# X
# ​
#  σ
# Y
# ​
#
# Cov(X,Y)
# ​
#
# Calculation:
# 𝑋
# ˉ
# =
# 2.5
# X
# ˉ
#  =2.5,
# 𝑌
# ˉ
# =
# 4.25
# Y
# ˉ
#  =4.25.
# Covariance = 2.92.
# Correlation = 0.98
